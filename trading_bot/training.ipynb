# %%
import numpy as np
from tqdm import tqdm
import logging
import coloredlogs
from keras.models import load_model

from agent import Agent, State
from utils import (
    get_state,
    get_data,
    format_currency,
    format_position,
    show_train_result,
    switch_k_backend_device,
    get_norm_candle,
    get_npast_data,
    get_data_small,
)

debug = True
logging.basicConfig(filename='training.log', encoding='utf-8', level=logging.DEBUG, force=True)
coloredlogs.install(level="DEBUG")
# switch_k_backend_device()

# %%
# Agent Params
# window_size = 10
strategy = "t-dqn"
pretrained = False
model_name = 'DQN-Trader'

# Training Params
batch_size = 32
ep_count = 100

# %%
filename = './data/btc_hourly_2018-2022.csv'
data = get_data(filename)
price_data = data[:,-3]
split_idx = round(len(data) * 0.7)
train_data, val_data = data[:split_idx], data[split_idx:]
initial_offset = val_data[1, -3] - val_data[0, -3]

# data = get_data_small(filename)
# state = get_state(data, 0, window_size + 1)
# print(state)

# %%
def create_state(data, t, lstm_model, balance, invested):
    candle = get_norm_candle(data, t)
    lstm_in = get_npast_data(data, t, 5)
    lstm_out = lstm_model.predict(lstm_in)[0][0]
    state = State(balance, invested, candle, lstm_out)

    return state

# perception models
lstm_model = load_model("../time_series_forecast/models/lstm_model_10")
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2022-05-29 20:53:15 LAPTOP-81OAJ65V tensorflow[31004] WARNING Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
init_state = create_state(data, 0, lstm_model, 1000, 0)

agent = Agent(init_state.size(), strategy=strategy, pretrained=pretrained, model_name=model_name)
# Out:
# 9

# %%
def train_model(agent, episode, data, ep_count=100, batch_size=32):
    total_profit = 0
    data_length = len(data) - 1

    avg_loss = []

    state = init_state

    for t in tqdm(range(data_length), total=data_length, leave=True, desc='Episode {}/{}'.format(episode, ep_count)):  
        reward = 0
        next_state = create_state(data, t + 1, lstm_model, state.balance, state.invested)

        # select an action
        action = agent.choose_action(state)

        # BUY
        if action[0] == 1:
            # agent.inventory.append(data[t])
            dollar_amount = action[1] * state.balance
            btc_amount = dollar_amount / price_data[t]

            next_state.balance -= dollar_amount
            next_state.invested += btc_amount
            if debug:
                logging.debug("# train # Buy at: {} | Amount: {}".format(format_currency(price_data[t]), format_currency(dollar_amount)))

        # SELL
        elif action[0] == 2:
            # bought_price = agent.inventory.pop(0)
            btc_amount = action[1] * state.invested
            dollar_amount = price_data[t] * btc_amount

            next_state.balance += dollar_amount
            next_state.invested -= btc_amount

            curr_net = next_state.get_net_worth(price_data[t])
            init_net = init_state.get_net_worth(price_data[t])

            new_profit = curr_net - init_net
            delta = new_profit - total_profit
            reward = delta #max(delta, 0)
            total_profit += delta
            if debug:
                logging.debug("-- train -- Sell at: {} | Amount: {} | Profit: {}".format(
                    format_currency(price_data[t]), format_currency(dollar_amount), format_position(total_profit)))

        # HOLD
        else:
            pass

        done = (t == data_length - 1)
        agent.remember(state.to_array(), action[0], reward, next_state.to_array(), done)

        if len(agent.memory) > batch_size:
            loss = agent.train_experience_replay(batch_size)
            avg_loss.append(loss)

        state = next_state

    if episode % 10 == 0:
        agent.save(episode)

    return (episode, ep_count, total_profit, np.mean(np.array(avg_loss)))


def evaluate_model(agent, data, debug):
    total_profit = 0
    data_length = len(data) - 1

    history = []
    # agent.inventory = []
    
    state = init_state

    for t in range(data_length):        
        reward = 0
        next_state = create_state(data, t + 1, lstm_model, state.balance, state.invested)
        
        # select an action
        action = agent.choose_action(state)

        # BUY
        if action[0] == 1:
            # agent.inventory.append(data[t])
            dollar_amount = action[1] * state.balance
            btc_amount = dollar_amount / price_data[t]

            next_state.balance -= dollar_amount
            next_state.invested += btc_amount
            if debug:
                logging.debug("# Validation # Buy at: {} | Amount: {}".format(format_currency(price_data[t]), format_currency(dollar_amount)))

        # SELL
        elif action[0] == 2:
            # bought_price = agent.inventory.pop(0)
            btc_amount = action[1] * state.invested
            dollar_amount = price_data[t] * btc_amount

            next_state.balance += dollar_amount
            next_state.invested -= btc_amount

            curr_net = next_state.get_net_worth(price_data[t])
            init_net = init_state.get_net_worth(price_data[t])

            new_profit = curr_net - init_net
            delta = new_profit - total_profit
            reward = delta #max(delta, 0)
            total_profit += delta
            if debug:
                logging.debug("# Validation # Sell at: {} | Amount: {} | Profit: {}".format(
                    format_currency(price_data[t]), format_currency(dollar_amount), format_position(total_profit)))

        # HOLD
        else:
            logging.debug("# Validation # HOLD")
            history.append((data[t], "HOLD"))

        done = (t == data_length - 1)
        agent.memory.append((state.to_array(), action[0], reward, next_state.to_array(), done))

        state = next_state
        if done:
            return total_profit, history

# %%
for episode in range(1, ep_count + 1):
        train_result = train_model(agent, episode, train_data, ep_count=ep_count,
                                        batch_size=batch_size)
        val_result, _ = evaluate_model(agent, val_data, debug)
        show_train_result(train_result, val_result, initial_offset)
# Out:
# Episode 1/100:   0%|          | 0/23280 [00:00<?, ?it/s]2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8740.99 | Amount: $0.00 | Profit: +$0.00
# 2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8728.49 | Amount: $623.71
# Episode 1/100:   0%|          | 3/23280 [00:00<19:39, 19.74it/s]2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8708.32 | Amount: $6.19
# 2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8795.90 | Amount: $164.39
# Episode 1/100:   0%|          | 5/23280 [00:00<21:02, 18.44it/s]2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8760.00 | Amount: $521.93 | Profit: +$1.62
# 2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8760.00 | Amount: $566.72
# 2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8759.23 | Amount: $767.33 | Profit: +$1.54
# Episode 1/100:   0%|          | 8/23280 [00:00<18:48, 20.62it/s]2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8517.77 | Amount: $53.09 | Profit: -$0.48
# 2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8520.30 | Amount: $210.66
# 2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8535.23 | Amount: $26.86 | Profit: -$0.07
# Episode 1/100:   0%|          | 11/23280 [00:00<17:25, 22.27it/s]2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8526.65 | Amount: $490.43
# 2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8555.60 | Amount: $83.15
# Episode 1/100:   0%|          | 14/23280 [00:00<16:35, 23.38it/s]2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8512.10 | Amount: $139.09
# 2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8492.28 | Amount: $20.58
# 2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8460.00 | Amount: $34.62
# Episode 1/100:   0%|          | 17/23280 [00:00<16:09, 23.99it/s]2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8326.28 | Amount: $0.86
# Episode 1/100:   0%|          | 20/23280 [00:00<16:04, 24.12it/s]2022-05-29 20:53:18 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8133.43 | Amount: $374.60 | Profit: -$44.73
# Episode 1/100:   0%|          | 23/23280 [00:01<16:58, 22.84it/s]2022-05-29 20:53:19 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8220.40 | Amount: $267.60
# 2022-05-29 20:53:19 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8238.80 | Amount: $447.54 | Profit: -$36.98
# 2022-05-29 20:53:19 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8232.99 | Amount: $280.70
# Episode 1/100:   0%|          | 26/23280 [00:01<17:09, 22.59it/s]2022-05-29 20:53:19 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8207.48 | Amount: $211.22
# Episode 1/100:   0%|          | 29/23280 [00:01<17:55, 21.62it/s]2022-05-29 20:53:19 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8365.08 | Amount: $756.42 | Profit: -$22.60
# Episode 1/100:   0%|          | 32/23280 [00:01<17:39, 21.95it/s]2022-05-29 20:53:25 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8273.40 | Amount: $267.51
# Episode 1/100:   0%|          | 35/23280 [00:09<5:30:25,  1.17it/s]2022-05-29 20:53:27 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8297.40 | Amount: $378.44 | Profit: -$22.88
# Episode 1/100:   0%|          | 37/23280 [00:14<8:01:03,  1.24s/it]2022-05-29 20:53:32 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8252.72 | Amount: $9.26 | Profit: -$22.98
# 2022-05-29 20:53:35 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8302.18 | Amount: $67.36
# Episode 1/100:   0%|          | 39/23280 [00:19<10:07:43,  1.57s/it]2022-05-29 20:53:37 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8295.85 | Amount: $38.63 | Profit: -$22.98
# Episode 1/100:   0%|          | 40/23280 [00:22<10:57:39,  1.70s/it]2022-05-29 20:53:40 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8277.25 | Amount: $177.94
# Episode 1/100:   0%|          | 41/23280 [00:24<11:50:55,  1.84s/it]2022-05-29 20:53:42 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8346.59 | Amount: $372.49
# Episode 1/100:   0%|          | 43/23280 [00:29<13:37:29,  2.11s/it]2022-05-29 20:53:47 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8375.10 | Amount: $320.80
# Episode 1/100:   0%|          | 44/23280 [00:32<14:12:20,  2.20s/it]2022-05-29 20:53:50 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8368.62 | Amount: $20.96
# Episode 1/100:   0%|          | 45/23280 [00:35<15:01:36,  2.33s/it]2022-05-29 20:53:53 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8366.72 | Amount: $28.92
# Episode 1/100:   0%|          | 47/23280 [00:40<15:56:19,  2.47s/it]2022-05-29 20:53:58 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8363.70 | Amount: $861.90 | Profit: -$20.51
# Episode 1/100:   0%|          | 48/23280 [00:42<15:59:29,  2.48s/it]2022-05-29 20:54:00 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8344.16 | Amount: $152.43
# Episode 1/100:   0%|          | 50/23280 [00:48<16:19:49,  2.53s/it]2022-05-29 20:54:06 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8277.40 | Amount: $253.25
# Episode 1/100:   0%|          | 52/23280 [00:53<17:29:26,  2.71s/it]2022-05-29 20:54:11 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8307.89 | Amount: $305.01
# Episode 1/100:   0%|          | 54/23280 [00:59<17:27:36,  2.71s/it]2022-05-29 20:54:17 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8269.47 | Amount: $170.72 | Profit: -$24.65
# Episode 1/100:   0%|          | 56/23280 [01:04<17:04:37,  2.65s/it]2022-05-29 20:54:22 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8318.49 | Amount: $109.56
# Episode 1/100:   0%|          | 58/23280 [01:09<16:34:23,  2.57s/it]2022-05-29 20:54:27 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8276.43 | Amount: $53.18 | Profit: -$24.67
# Episode 1/100:   0%|          | 59/23280 [01:12<16:44:20,  2.60s/it]2022-05-29 20:54:30 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8257.69 | Amount: $433.04 | Profit: -$26.23
# Episode 1/100:   0%|          | 62/23280 [01:19<16:41:56,  2.59s/it]2022-05-29 20:54:37 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8200.70 | Amount: $37.42 | Profit: -$28.01
# Episode 1/100:   0%|          | 63/23280 [01:22<16:28:29,  2.55s/it]2022-05-29 20:54:40 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8155.41 | Amount: $125.89 | Profit: -$29.21
# Episode 1/100:   0%|          | 64/23280 [01:24<16:18:47,  2.53s/it]2022-05-29 20:54:42 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8080.00 | Amount: $482.72
# Episode 1/100:   0%|          | 65/23280 [01:27<16:23:54,  2.54s/it]2022-05-29 20:54:45 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8067.03 | Amount: $323.52
# Episode 1/100:   0%|          | 66/23280 [01:29<16:40:31,  2.59s/it]2022-05-29 20:54:47 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $7958.08 | Amount: $39.00
# Episode 1/100:   0%|          | 67/23280 [01:32<16:28:34,  2.56s/it]2022-05-29 20:54:50 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $7974.25 | Amount: $495.57 | Profit: -$41.18
# Episode 1/100:   0%|          | 69/23280 [01:37<16:38:37,  2.58s/it]2022-05-29 20:54:55 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $7991.99 | Amount: $290.20 | Profit: -$40.23
# Episode 1/100:   0%|          | 70/23280 [01:40<16:42:57,  2.59s/it]2022-05-29 20:54:58 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8022.70 | Amount: $618.26
# Episode 1/100:   0%|          | 71/23280 [01:42<16:29:11,  2.56s/it]2022-05-29 20:55:00 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8042.97 | Amount: $114.92
# Episode 1/100:   0%|          | 72/23280 [01:45<16:47:04,  2.60s/it]2022-05-29 20:55:03 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $7965.67 | Amount: $45.74
# Episode 1/100:   0%|          | 73/23280 [01:47<16:33:59,  2.57s/it]2022-05-29 20:55:05 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8088.95 | Amount: $27.11
# Episode 1/100:   0%|          | 74/23280 [01:50<16:24:53,  2.55s/it]2022-05-29 20:55:08 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8122.19 | Amount: $1.73
# Episode 1/100:   0%|          | 76/23280 [01:55<16:26:38,  2.55s/it]2022-05-29 20:55:13 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8137.73 | Amount: $905.09 | Profit: -$26.32
# Episode 1/100:   0%|          | 79/23280 [02:03<16:35:05,  2.57s/it]2022-05-29 20:55:21 LAPTOP-81OAJ65V root[31004] DEBUG -- train -- Sell at: $8094.40 | Amount: $27.50 | Profit: -$26.62
# Episode 1/100:   0%|          | 80/23280 [02:05<16:36:23,  2.58s/it]2022-05-29 20:55:23 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8080.01 | Amount: $819.62
# Episode 1/100:   0%|          | 81/23280 [02:08<16:25:01,  2.55s/it]2022-05-29 20:55:26 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8117.09 | Amount: $96.75
# Episode 1/100:   0%|          | 82/23280 [02:10<16:41:42,  2.59s/it]2022-05-29 20:55:29 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8126.99 | Amount: $29.04
# Episode 1/100:   0%|          | 84/23280 [02:16<16:41:57,  2.59s/it]2022-05-29 20:55:34 LAPTOP-81OAJ65V root[31004] DEBUG # train # Buy at: $8215.39 | Amount: $0.01
# Episode 1/100:   0%|          | 85/23280 [02:19<10:36:18,  1.65s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\FRI\Masters\UI\UI-2022\trading_bot\training.ipynb Cell 7' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/FRI/Masters/UI/UI-2022/trading_bot/training.ipynb#ch0000005?line=0'>1</a> for episode in range(1, ep_count + 1):
# ----> <a href='vscode-notebook-cell:/d%3A/FRI/Masters/UI/UI-2022/trading_bot/training.ipynb#ch0000005?line=1'>2</a>         train_result = train_model(agent, episode, train_data, ep_count=ep_count,
#       <a href='vscode-notebook-cell:/d%3A/FRI/Masters/UI/UI-2022/trading_bot/training.ipynb#ch0000005?line=2'>3</a>                                         batch_size=batch_size)
#
# d:\FRI\Masters\UI\UI-2022\trading_bot\training.ipynb Cell 6' in train_model(agent, episode, data, ep_count, batch_size)
#      <a href='vscode-notebook-cell:/d%3A/FRI/Masters/UI/UI-2022/trading_bot/training.ipynb#ch0000004?line=51'>52</a> agent.remember(state.to_array(), action[0], reward, next_state.to_array(), done)
#      <a href='vscode-notebook-cell:/d%3A/FRI/Masters/UI/UI-2022/trading_bot/training.ipynb#ch0000004?line=53'>54</a> if len(agent.memory) > batch_size:
# ---> <a href='vscode-notebook-cell:/d%3A/FRI/Masters/UI/UI-2022/trading_bot/training.ipynb#ch0000004?line=54'>55</a>     loss = agent.train_experience_replay(batch_size)
#      <a href='vscode-notebook-cell:/d%3A/FRI/Masters/UI/UI-2022/trading_bot/training.ipynb#ch0000004?line=55'>56</a>     avg_loss.append(loss)
#      <a href='vscode-notebook-cell:/d%3A/FRI/Masters/UI/UI-2022/trading_bot/training.ipynb#ch0000004?line=57'>58</a> state = next_state
#
# File d:\FRI\Masters\UI\UI-2022\trading_bot\agent.py:159, in Agent.train_experience_replay(self, batch_size)
#     <a href='file:///d%3A/FRI/Masters/UI/UI-2022/trading_bot/agent.py?line=155'>156</a>     target = reward + self.gamma * np.amax(self.target_model.predict(next_state)[0])
#     <a href='file:///d%3A/FRI/Masters/UI/UI-2022/trading_bot/agent.py?line=157'>158</a> # estimate q-values based on current state
# --> <a href='file:///d%3A/FRI/Masters/UI/UI-2022/trading_bot/agent.py?line=158'>159</a> q_values = self.model.predict(state)
#     <a href='file:///d%3A/FRI/Masters/UI/UI-2022/trading_bot/agent.py?line=159'>160</a> # update the target for current action based on discounted reward
#     <a href='file:///d%3A/FRI/Masters/UI/UI-2022/trading_bot/agent.py?line=160'>161</a> q_values[0][action] = target
#
# File c:\Users\timvu\miniconda3\envs\ui\lib\site-packages\keras\engine\training.py:1720, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1713'>1714</a>   except ValueError:
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1714'>1715</a>     warnings.warn('Using Model.predict with '
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1715'>1716</a>                   'MultiWorkerDistributionStrategy or TPUStrategy and '
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1716'>1717</a>                   'AutoShardPolicy.FILE might lead to out-of-order result'
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1717'>1718</a>                   '. Consider setting it to AutoShardPolicy.DATA.')
# -> <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1719'>1720</a> data_handler = data_adapter.get_data_handler(
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1720'>1721</a>     x=x,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1721'>1722</a>     batch_size=batch_size,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1722'>1723</a>     steps_per_epoch=steps,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1723'>1724</a>     initial_epoch=0,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1724'>1725</a>     epochs=1,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1725'>1726</a>     max_queue_size=max_queue_size,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1726'>1727</a>     workers=workers,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1727'>1728</a>     use_multiprocessing=use_multiprocessing,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1728'>1729</a>     model=self,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1729'>1730</a>     steps_per_execution=self._steps_per_execution)
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1731'>1732</a> # Container that configures and calls `tf.keras.Callback`s.
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/training.py?line=1732'>1733</a> if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\timvu\miniconda3\envs\ui\lib\site-packages\keras\engine\data_adapter.py:1383, in get_data_handler(*args, **kwargs)
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1380'>1381</a> if getattr(kwargs["model"], "_cluster_coordinator", None):
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1381'>1382</a>   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1382'>1383</a> return DataHandler(*args, **kwargs)
#
# File c:\Users\timvu\miniconda3\envs\ui\lib\site-packages\keras\engine\data_adapter.py:1138, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1134'>1135</a>   self._steps_per_execution_value = steps_per_execution.numpy().item()
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1136'>1137</a> adapter_cls = select_data_adapter(x, y)
# -> <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1137'>1138</a> self._adapter = adapter_cls(
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1138'>1139</a>     x,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1139'>1140</a>     y,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1140'>1141</a>     batch_size=batch_size,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1141'>1142</a>     steps=steps_per_epoch,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1142'>1143</a>     epochs=epochs - initial_epoch,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1143'>1144</a>     sample_weights=sample_weight,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1144'>1145</a>     shuffle=shuffle,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1145'>1146</a>     max_queue_size=max_queue_size,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1146'>1147</a>     workers=workers,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1147'>1148</a>     use_multiprocessing=use_multiprocessing,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1148'>1149</a>     distribution_strategy=tf.distribute.get_strategy(),
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1149'>1150</a>     model=model)
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1151'>1152</a> strategy = tf.distribute.get_strategy()
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=1153'>1154</a> self._current_step = 0
#
# File c:\Users\timvu\miniconda3\envs\ui\lib\site-packages\keras\engine\data_adapter.py:286, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=279'>280</a>   return indices
#     <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=281'>282</a> # We prefetch a single element. Computing large permutations can take quite
#     <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=282'>283</a> # a while so we don't want to wait for prefetching over an epoch boundary to
#     <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=283'>284</a> # trigger the next permutation. On the other hand, too many simultaneous
#     <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=284'>285</a> # shuffles can contend on a hardware level and degrade all performance.
# --> <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=285'>286</a> indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=287'>288</a> def slice_batch_indices(indices):
#     <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=288'>289</a>   """Convert a Tensor of indices into a dataset of batched indices.
#     <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=289'>290</a>
#     <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=290'>291</a>   This step can be accomplished in several ways. The most natural is to
#    (...)
#     <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=301'>302</a>     A Dataset of batched indices.
#     <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/keras/engine/data_adapter.py?line=302'>303</a>   """
#
# File c:\Users\timvu\miniconda3\envs\ui\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:1861, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic)
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=1857'>1858</a>   if deterministic is not None and not DEBUG_MODE:
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=1858'>1859</a>     warnings.warn("The `deterministic` argument has no effect unless the "
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=1859'>1860</a>                   "`num_parallel_calls` argument is specified.")
# -> <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=1860'>1861</a>   return MapDataset(self, map_func, preserve_cardinality=True)
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=1861'>1862</a> else:
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=1862'>1863</a>   return ParallelMapDataset(
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=1863'>1864</a>       self,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=1864'>1865</a>       map_func,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=1865'>1866</a>       num_parallel_calls,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=1866'>1867</a>       deterministic,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=1867'>1868</a>       preserve_cardinality=True)
#
# File c:\Users\timvu\miniconda3\envs\ui\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4986, in MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4979'>4980</a> self._preserve_cardinality = preserve_cardinality
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4980'>4981</a> self._map_func = StructuredFunctionWrapper(
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4981'>4982</a>     map_func,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4982'>4983</a>     self._transformation_name(),
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4983'>4984</a>     dataset=input_dataset,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4984'>4985</a>     use_legacy_function=use_legacy_function)
# -> <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4985'>4986</a> variant_tensor = gen_dataset_ops.map_dataset(
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4986'>4987</a>     input_dataset._variant_tensor,  # pylint: disable=protected-access
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4987'>4988</a>     self._map_func.function.captured_inputs,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4988'>4989</a>     f=self._map_func.function,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4989'>4990</a>     use_inter_op_parallelism=self._use_inter_op_parallelism,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4990'>4991</a>     preserve_cardinality=self._preserve_cardinality,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4991'>4992</a>     **self._flat_structure)
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4992'>4993</a> super(MapDataset, self).__init__(input_dataset, variant_tensor)
#
# File c:\Users\timvu\miniconda3\envs\ui\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3169, in map_dataset(input_dataset, other_arguments, f, output_types, output_shapes, use_inter_op_parallelism, preserve_cardinality, name)
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=3166'>3167</a> if tld.is_eager:
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=3167'>3168</a>   try:
# -> <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=3168'>3169</a>     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=3169'>3170</a>       _ctx, "MapDataset", name, input_dataset, other_arguments, "f", f,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=3170'>3171</a>       "output_types", output_types, "output_shapes", output_shapes,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=3171'>3172</a>       "use_inter_op_parallelism", use_inter_op_parallelism,
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=3172'>3173</a>       "preserve_cardinality", preserve_cardinality)
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=3173'>3174</a>     return _result
#    <a href='file:///c%3A/Users/timvu/miniconda3/envs/ui/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=3174'>3175</a>   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
